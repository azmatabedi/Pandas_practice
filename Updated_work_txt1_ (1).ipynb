# %%
80from IPython.core.display import HTML
HTML('''
<script>
var logoParent = document.getElementById("kernel_logo_widget")
var logo = document.getElementById("kernel_logo_widget").getElementsByClassName("current_kernel_logo")[0];
logo.src = "https://i.ibb.co/mD4jTGQ/itclogo.jpg";
logo.style = "display: inline; width:138px; height:40px";
logoParent.innerHTML = '<a href="https://i.ibb.co/mD4jTGQ/itclogo.jpg">' + logoParent.innerHTML + '</a>';
</script>
''')
# Out:
#   File "<ipython-input-2-7398fa5276d8>", line 1
#     80from IPython.core.display import HTML
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# <font size="36"><b>Pandas - Assignment 1</b></font> <img src = "https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/03/pandas.jpg" height=200 width=200>

# %% [markdown]
# ## Topics covered:
# - Setting and changing index and column names
# - Data Types
# - Basic information about the Data Frame
# - Operations on values of DFs
# - Indexing and conditional selection
# - Changing DataFrames by direct operations or with `apply`

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Question 0

# %% [markdown]
# Print your `pandas` version

# %%
pd.__version__
# Out:
# '1.1.5'

# %% [markdown]
# # Question 1

# %% [markdown]
# #### 1a. Read a CSV file from "https://raw.githubusercontent.com/selva86/datasets/master/College.csv" into DataFrame `df`

# %% [markdown]
# The specific dataset columns:
# - `Private` - Whether the college is public or private
# - `Apps` - Number of applications received
# - `Accept` - Number of applications accepted
# - `Enroll` - Number of new students enrolled
# - `Top10perc` - Percentage of new students from top 10% of High School class
# - `Top25perc` - Percentage new students from top 25% of High School class
# - `F.Undergrad` - Number of fulltime undergraduates
# - `P.Undergrad` - Number of parttime undergraduates
# - `Outstate` - Out-of-state tuition
# - `Room.Board` - Room and board costs
# - `Books` - Estimated book costs
# - `Personal` - Estimated personal spending
# - `PhD` - Percentage of faculty with Ph.D.’s
# - `Terminal` - Percentage of faculty with terminal degree
# - `S.F.Ratio` - Student/faculty ratio
# - `perc.alumni` - Percentage alumni who donate
# - `Expend` - Instructional expenditure per student
# - `Grad.Rate` - Graduation rate

# %%
df=pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/College.csv")
df
# Out:
#     Private   Apps  Accept  Enroll  ...  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       Yes   1660    1232     721  ...       18.1           12    7041         60
# 1       Yes   2186    1924     512  ...       12.2           16   10527         56
# 2       Yes   1428    1097     336  ...       12.9           30    8735         54
# 3       Yes    417     349     137  ...        7.7           37   19016         59
# 4       Yes    193     146      55  ...       11.9            2   10922         15
# ..      ...    ...     ...     ...  ...        ...          ...     ...        ...
# 772      No   2197    1515     543  ...       21.0           14    4469         40
# 773     Yes   1959    1805     695  ...       13.3           31    9189         83
# 774     Yes   2097    1915     695  ...       14.4           20    8323         49
# 775     Yes  10705    2453    1317  ...        5.8           49   40386         99
# ...

# %% [markdown]
# #### 1b. Show the information for the first 8 colleges

# %%
df.iloc[0:8,]
# Out:
#   Private  Apps  Accept  Enroll  ...  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0     Yes  1660    1232     721  ...       18.1           12    7041         60
# 1     Yes  2186    1924     512  ...       12.2           16   10527         56
# 2     Yes  1428    1097     336  ...       12.9           30    8735         54
# 3     Yes   417     349     137  ...        7.7           37   19016         59
# 4     Yes   193     146      55  ...       11.9            2   10922         15
# 5     Yes   587     479     158  ...        9.4           11    9727         55
# 6     Yes   353     340     103  ...       11.5           26    8861         63
# 7     Yes  1899    1720     489  ...       13.7           37   11487         73
#
# [8 rows x 18 columns]

# %% [markdown]
# #### 1c. Show 8 random colleges' information

# %%
x=np.random.randint(776,size=8)
for i in x:
  print(df.iloc[i-1:i,:])
# Out:
#     Private  Apps  Accept  Enroll  ...  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 462     Yes   516     392     154  ...       14.0           36    9315         58
#
# [1 rows x 18 columns]
#     Private  Apps  Accept  Enroll  ...  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 499     Yes   876     802     367  ...       18.8           19    5081         78
#
# [1 rows x 18 columns]
#     Private  Apps  Accept  Enroll  ...  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 111     Yes   880     520     224  ...       11.1           24    8129         63
#
# [1 rows x 18 columns]
#     Private  Apps  Accept  Enroll  ...  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 134     Yes   546     447     189  ...       14.0            7    8820         80
#
# [1 rows x 18 columns]
#     Private  Apps  Accept  Enroll  ...  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 283     Yes  2421    2109     820  ...       14.5           28    7738         89
#
# [1 rows x 18 columns]
# ...

# %% [markdown]
# # Question 2

# %% [markdown]
# #### 2a: What are the column names of the DataFrame?

# %%
df.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate'],
#       dtype='object')

# %% [markdown]
# #### 2b: What are the indexes of the df?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=777, step=1)

# %% [markdown]
# #### 2c: You were given the following index for your dataframe after the fact with names of colleges.  Use it as the new index of the df

# %%
college_names = [f'College{i}' for i in range(1,778) ]

# %%
df.index=college_names
df
# Out:
#            Private   Apps  Accept  ...  perc.alumni  Expend  Grad.Rate
# College1       Yes   1660    1232  ...           12    7041         60
# College2       Yes   2186    1924  ...           16   10527         56
# College3       Yes   1428    1097  ...           30    8735         54
# College4       Yes    417     349  ...           37   19016         59
# College5       Yes    193     146  ...            2   10922         15
# ...            ...    ...     ...  ...          ...     ...        ...
# College773      No   2197    1515  ...           14    4469         40
# College774     Yes   1959    1805  ...           31    9189         83
# College775     Yes   2097    1915  ...           20    8323         49
# College776     Yes  10705    2453  ...           49   40386         99
# College777     Yes   2989    1855  ...           28    4509         99
#
# [777 rows x 18 columns]

# %% [markdown]
# # Question 3

# %% [markdown]
# #### This database is old, update the prices for inflation. Change the columns `Room.Board`, `Books`, `Personal` in the original DataFrame to have the prices raised by 50%, but keep the values as integers since they are approximate anyways

# %%
print(df.iloc[:5,10])
Room_Board=df['Room.Board']+df['Room.Board']*.5
Books=df.Books+df.Books*.5
Personal=df.Personal+df.Personal*.5
df['Room.Board']=Room_Board
df['Books']=Books
df['Personal']=Personal
print('updated dataset\n')
print(df.iloc[:5,10])
# Out:
# College1    450
# College2    750
# College3    400
# College4    450
# College5    800
# Name: Books, dtype: int64
# updated dataset
#
# College1     675.0
# College2    1125.0
# College3     600.0
# College4     675.0
# College5    1200.0
# Name: Books, dtype: float64

# %% [markdown]
# # Question 4

# %% [markdown]
# #### Using a `describe` function, and indexing, give in line of code the information about minimum & maximum values and 25, 50 & 75 percentiles of all the numeric columns

# %%
percent=[.25,.50,.75]
x=df.describe(percentiles=percent)
x
# Out:
#                Apps        Accept  ...        Expend  Grad.Rate
# count    777.000000    777.000000  ...    777.000000  777.00000
# mean    3001.638353   2018.804376  ...   9660.171171   65.46332
# std     3870.201484   2451.113971  ...   5221.768440   17.17771
# min       81.000000     72.000000  ...   3186.000000   10.00000
# 25%      776.000000    604.000000  ...   6751.000000   53.00000
# 50%     1558.000000   1110.000000  ...   8377.000000   65.00000
# 75%     3624.000000   2424.000000  ...  10830.000000   78.00000
# max    48094.000000  26330.000000  ...  56233.000000  118.00000
#
# [8 rows x 17 columns]

# %% [markdown]
# # Question 5

# %% [markdown]
# #### 5a. How many unique values are there in `PhD` column?

# %%
print("total number of unique values ",len(df.PhD.unique()))
# Out:
# total number of unique values  78

# %% [markdown]
# #### 5b. What are the unique values in the `PhD` column?

# %%
df.PhD.unique()
# Out:
# array([ 70,  29,  53,  92,  76,  67,  90,  89,  79,  40,  82,  73,  60,
#         36,  78,  93,  48,  62,  69,  83,  55,  88,  57,  85,  65,  66,
#         81,  59,  58,  68,  98,  71,  74,  61,  87,  64,  35,  80,  63,
#         75,  39,  99, 100,  95,  77,  72,  10,  86,  22,  50,  41,   8,
#         94,  56,  46,  54,  84,  97,  51,  42,  49,  52,  43,  37,  45,
#         47,  91,  25,  31,  96,  34,  33,  44,  32,  14, 103,  26,  16])

# %% [markdown]
# #### 5c. What's the 5 most common `PhD` percentages in `Private` universities, and how many times do they appear? Present an answer as a nice Series with meaningful name and index and have the type as `float`

# %%
x=df['PhD'].value_counts()
z=df.Private[df.Private=='Yes']
print("5 most common " ,x[:5],"Private universitires",z[:5])
# Out:
# 5 most common  77    26
# 73    24
# 90    23
# 81    21
# 82    21
# Name: PhD, dtype: int64 Private universitires College1    Yes
# College2    Yes
# College3    Yes
# College4    Yes
# College5    Yes
# Name: Private, dtype: object

# %% [markdown]
# # Question 6

# %% [markdown]
# #### We want to check if the data is ordered in some way and should be shuffled, or we can assume that it's randomly ordered.  We decide to check it by checking the statistical information by looking at the first and second half of the rows of the DF.  Would you say the order is random enough?  You can just compare visually (no need to write code to make the actual comparison)
# #### Warning: Do not use magic numbers.

# %%
import matplotlib.pyplot as plt
names=df.columns
value=df.values
y=0
for i in names:
  print("column name",i)
  Y=value[:,y]
  plt.plot(Y)
  plt.show()
  y+=1
# Out:
# column name Private
# column name Apps
# column name Accept
# column name Enroll
# column name Top10perc
# column name Top25perc
# column name F.Undergrad
# column name P.Undergrad
# column name Outstate
# column name Room.Board
# column name Books
# column name Personal
# column name PhD
# column name Terminal
# column name S.F.Ratio
# column name perc.alumni
# column name Expend
# column name Grad.Rate

# %% [markdown]
# ## Question 7

# %% [markdown]
# #### 7a. There are too many columns in this DataFrame, we want a new DataFrame with less columns.  Combine `Room.Board`, `Books`, `Personal` into 1 column `Full cost` in the original DF.  Use `sum` instead of `+`

# %%
#your code here
columns_to_sum = ['Room.Board','Books','Personal']
df['Full Cost']= df[columns_to_sum].sum(axis=1)
df
# Out:
#            Private   Apps  Accept  ...  Expend  Grad.Rate  Full Cost
# College1       Yes   1660    1232  ...    7041         60     8925.0
# College2       Yes   2186    1924  ...   10527         56    13050.0
# College3       Yes   1428    1097  ...    8735         54     7972.5
# College4       Yes    417     349  ...   19016         59    10162.5
# College5       Yes    193     146  ...   10922         15     9630.0
# ...            ...    ...     ...  ...     ...        ...        ...
# College773      No   2197    1515  ...    4469         40     8400.0
# College774     Yes   1959    1805  ...    9189         83    10215.0
# College775     Yes   2097    1915  ...    8323         49     8397.0
# College776     Yes  10705    2453  ...   40386         99    13882.5
# College777     Yes   2989    1855  ...    4509         99     7965.0
#
# [777 rows x 19 columns]

# %% [markdown]
# #### 7b. Add a new column `% part time` that calculates % of part time undergraduates out of total undergraduates (see legend above to decide how to calculate this) with integer percents using `apply` with values `high` (for >20%), `medium` (between 10 and 20% including), `low` (for <10%).

# %%
#your code here
def func(x, y=0):
      if x > 20 and x > y:
          return 'high'
      if x>10 and x<20 and x>y:
          return 'medium'
      else:
          return 'low'

df['% part time'] = (df['P.Undergrad']/df['F.Undergrad'])*100
df['% part time'] = df['% part time'].apply(func)
df
# Out:
#            Private   Apps  Accept  ...  Grad.Rate  Full Cost  % part time
# College1       Yes   1660    1232  ...         60     8925.0       medium
# College2       Yes   2186    1924  ...         56    13050.0         high
# College3       Yes   1428    1097  ...         54     7972.5          low
# College4       Yes    417     349  ...         59    10162.5       medium
# College5       Yes    193     146  ...         15     9630.0         high
# ...            ...    ...     ...  ...        ...        ...          ...
# College773      No   2197    1515  ...         40     8400.0         high
# College774     Yes   1959    1805  ...         83    10215.0         high
# College775     Yes   2097    1915  ...         49     8397.0          low
# College776     Yes  10705    2453  ...         99    13882.5          low
# College777     Yes   2989    1855  ...         99     7965.0         high
#
# [777 rows x 20 columns]

# %% [markdown]
# #### 7c. Would you say there are more colleges with < 10% or > 20% part time students?

# %%
#your code here
val = df['% part time'].value_counts(ascending=True)
if val.high > val.low:
  print('more colleges with >20% part time students')
else:
  print('more colleges with >10% part time students')
# Out:
# more colleges with >20% part time students

# %% [markdown]
# ## Question 8

# %% [markdown]
# #### 8a. By what percent is the maximum `Full cost` greater in private colleges vs. public colleges?

# %%
#your code here
# df1 = df['Private']
# df1
val = df[df['Private']=='No']
val
val1 = df[df['Private']=='Yes']
val1
p1 = val['Full Cost'].sum()
p2 = val1['Full Cost'].sum()
p1 = (p1/df['Full Cost'].sum())*100
p2 = (p2/df['Full Cost'].sum())*100
print(p2-p1)
# Out:
# 47.77154327277043

# %% [markdown]
# #### 8b. By what percent is the average `Full cost` greater in private colleges vs. public colleges?

# %%
#your code here
avg1 = val['Full Cost'].mean()
avg2 = val1['Full Cost'].mean()
avg1 = (avg1/df['Full Cost'].mean())*100
avg2 = (avg2/df['Full Cost'].mean())*100
print(avg2-avg1)
# Out:
# 5.89817185058611
